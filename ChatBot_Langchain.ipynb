# %% [markdown]
# <a href="https://colab.research.google.com/github/Nimalnix/AIML/blob/main/ChatBot_Langchain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install langchain python-dotenv streamlit tiktoken faiss-cpu protobuf openai InstructorEmbedding
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 44.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 35.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 33.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 12.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 49.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 10.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 7.0.0
#     Uninstalling importlib-metadata-7.0.0:
#       Successfully uninstalled importlib-metadata-7.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !pip install sentence_transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 1.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 15.2 MB/s eta 0:00:00
# ...
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=822708804af6989dadb405c831ed984f97775cd698732cf17063e7fb1ff114e6
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence_transformers
# ...

# %%
# !pip install pandas

# %%
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.1/803.1 kB 11.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 67.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.7/205.7 kB 22.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.8 MB/s eta 0:00:00
# ...

# %%
# !pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.4/225.4 kB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.9.0 which is incompatible.
# ...

# %%
from langchain.llms import OpenAI
import os

# %%
os.environ['OPENAI_API_KEY'] = "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"
llm = OpenAI(temperature=0.7)

# %%
poem = llm("carols of the bells lyrics")
print(poem)
# Out:
# Hark! how the bells
# Sweet silver bells
# All seem to say
# "Throw cares away."
# Christmas is here
# Bringing good

# %%
from langchain.vectorstores import FAISS
from langchain.llms import GooglePalm
from langchain.llms import OpenAI
from langchain.document_loaders.csv_loader import CSVLoader
from langchain.embeddings import HuggingFaceInstructEmbeddings
from langchain.prompts import PromptTemplate
from langchain.chains import RetrievalQA

# %%
from langchain.chains import RetrievalQA


from langchain.embeddings import GooglePalmEmbeddings
from langchain.llms import GooglePalm

# %%
loader = CSVLoader(file_path='/content/HospitalQue.csv', source_column="prompt")

data = loader.load()

# %%
data
# Out:
# [Document(page_content='prompt: How is the total bill amount determined for a hospital stay?\nresponse: The total bill amount is determined by considering various factors, including room charges, medical procedures, diagnostic tests, medications, physician fees, and any additional services provided during the hospital stay.', metadata={'source': 'How is the total bill amount determined for a hospital stay?', 'row': 0}),
#  Document(page_content="prompt: What is the difference between in-network and out-of-network charges?\nresponse: In-network charges typically refer to services provided by healthcare providers who have agreed to participate in the insurance plan's network, resulting in lower costs for the patient. Out-of-network charges involve services provided by healthcare providers who are not part of the insurance plan's network, leading to higher out-of-pocket expenses.", metadata={'source': 'What is the difference between in-network and out-of-network charges?', 'row': 1}),
# ...

# %%
instructor_embeddings = HuggingFaceInstructEmbeddings(model_name="hkunlp/instructor-large")

e = instructor_embeddings.embed_query("What is your refund policy?")
# Out:
# .gitattributes:   0%|          | 0.00/1.48k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/270 [00:00<?, ?B/s]
# 2_Dense/config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/3.15M [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/66.3k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.53k [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.41k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/461 [00:00<?, ?B/s]
# load INSTRUCTOR_Transformer
# max_seq_length  512

# %%
len(e)
# Out:
# 768

# %%
e[:5]

# %%
from langchain.vectorstores import FAISS


vectordb = FAISS.from_documents(documents=data,
                                 embedding=instructor_embeddings)

retriever = vectordb.as_retriever(score_threshold = 0.7)

# %%
rdocs = retriever.get_relevant_documents("can you explain about co-pay")
rdocs
# Out:
# [Document(page_content='prompt: What does the term "co-pay" mean in hospital billing?\nresponse: A co-pay is a fixed amount that a patient is required to pay for certain covered services, typically due at the time of service. It is a form of cost-sharing between the patient and the insurance company.', metadata={'source': 'What does the term "co-pay" mean in hospital billing?', 'row': 3}),
#  Document(page_content="prompt: Can I negotiate or set up a payment plan for the portion of the bill not covered by insurance?\nresponse: Yes, many hospitals are willing to work with patients to establish payment plans or negotiate the portion of the bill not covered by insurance. It's advisable to communicate with the hospital's billing department to discuss available options.", metadata={'source': 'Can I negotiate or set up a payment plan for the portion of the bill not covered by insurance?', 'row': 16}),
# ...

# %%
from langchain.prompts import PromptTemplate

prompt_template = """Given the following context and a question, generate an answer based on this context only.
In the answer try to provide as much text as possible from "response" section in the source document context without making much changes.
If the answer is not found in the context, kindly state "I don't know." Don't try to make up an answer.

CONTEXT: {context}

QUESTION: {question}"""


PROMPT = PromptTemplate(
    template=prompt_template, input_variables=["context", "question"]
)
chain_type_kwargs = {"prompt": PROMPT}


from langchain.chains import RetrievalQA

chain = RetrievalQA.from_chain_type(llm=llm,
                            chain_type="stuff",
                            retriever=retriever,
                            input_key="query",
                            return_source_documents=True,
                            chain_type_kwargs=chain_type_kwargs)

# %%
chain("How is the total bill amount determined for a hospital stay and How can I check the status of my insurance claim?")
# Out:
# {'query': 'How is the total bill amount determined for a hospital stay and How can I check the status of my insurance claim?',
#  'result': '\nANSWER: The total bill amount is determined by considering various factors, including room charges, medical procedures, diagnostic tests, medications, physician fees, and any additional services provided during the hospital stay. Accurate billing requires providing correct personal information, insurance details, and a comprehensive list of services received during the hospital stay. Patients can verify and update their information at the time of registration to help ensure accurate billing. The processing time for insurance claims varies, but it typically takes a few weeks. Patients can expect to receive a final bill after the insurance company has processed the claim, and any remaining balance will be outlined in the bill.',
# ...

# %%
chain("How does coordination of benefits work if I have multiple insurance plans and What does the term co-pay mean in hospital billing?")
# Out:
# {'query': 'How does coordination of benefits work if I have multiple insurance plans and What does the term co-pay mean in hospital billing?',
#  'result': '\n\nANSWER: Coordination of benefits (COB) is the process used by insurance companies to determine which plan pays first when a patient has coverage under multiple insurance plans. The primary insurance plan pays its share first, and the secondary plan may cover additional costs. A co-pay is a fixed amount that a patient is required to pay for certain covered services, typically due at the time of service. It is a form of cost-sharing between the patient and the insurance company.',
# ...
